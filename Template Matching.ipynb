# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full = cv2.imread('C:/Users/Khaled/Documents/CV Course/1/Computer-Vision-with-Python/DATA/sammy.jpg')
full = cv2.cvtColor(full,cv2.COLOR_BGR2RGB)
plt.imshow(full)

# %%
face = cv2.imread('C:/Users/Khaled/Documents/CV Course/1/Computer-Vision-with-Python/DATA/sammy_face.jpg')
full = cv2.cvtColor(face,cv2.COLOR_BGR2RGB)
plt.imshow(full)

# %%
#-------------------------------------------------------------------------------------------------------
sum([1,2,3]) # -----> 6
mystring='sum' # ----> error
eval(mystring)
myfunc = eval(mystring)
myfunc([1,2,3])
# Out:
# 6

# %%
# All the 6 methods for comparison in a list
# Note how we are using strings, later on we'll use the eval() function to convert to function
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 
           'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:
    
    # create a copy 
    full_copy = full.copy()
    
    method = eval(m)
    
    # TEMPLATE MATCHING
    res = cv2.matchTemplate(full_copy,face,method)
    
    min_value,max_value,min_loc,max_loc = cv2.minMaxLoc(res)
    # returns the minimum and maximum values and loaction of these values in an image
    
    if method in [cv2.TM_SQDIFF,cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
        
    height,width,channels = face.shape
    
    bottom_right = (top_left[0]+width,top_left[1]+height)
    
    cv2.rectangle(full_copy,top_left,bottom_right,(255,0,0),10)
    
    # Plot the Images
    plt.subplot(121)
    plt.imshow(res)
    plt.title('Result of Template Matching')
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title('Detected Point')
    plt.suptitle(m)
    
    
    plt.show()
    print('\n')
    print('\n')

# %%
my_method = eval('cv2.TM_CCOEFF')
# apply template matching which returns a heat map of different lights
res = cv2.matchTemplate(full,face,cv2.TM_CCOEFF)
plt.imshow(res)
